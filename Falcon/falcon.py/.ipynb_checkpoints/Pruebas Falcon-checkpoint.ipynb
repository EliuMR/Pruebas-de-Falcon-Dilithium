# %%
import falcon
sk = falcon.SecretKey(512)
pk = falcon.PublicKey(sk) 
print(type(sk))
# Out:
# <class 'falcon.SecretKey'>

# %%
sig = sk.sign(b"Hello")
print(pk.verify(b"Hello", sig))
# Out:
# True

# %%
print(pk.verify(b"Hel1o", sig))
# Out:
# Squared norm of signature is too large: 6406431759
# False

# %%
sk_ = falcon.SecretKey(512)
pk_ = falcon.PublicKey(sk_)

# %%
print(pk_.verify(b"Hello", sig))
# Out:
# Squared norm of signature is too large: 6283853376
# False

# %%
import time

# %%
mensajes=[b"Sol y mar.",b"Cielo azul y sol.",b"Amigos disfrutan el dia juntos.",b"La musica suena en la noche, creando recuerdos inolvidables.",b"En la vasta pradera, los caballos galopan libremente mientras el viento sopla suavemente.",b"En el tranquilo pueblo costero, las olas rompen suavemente en la playa dorada, creando un paisaje de serenidad.",b"Bajo el cielo estrellado, un poeta inspirado escribe versos que capturan la belleza y la melancolia de la noche, mientras que los corazones sensibles encuentran consuelo en sus palabras.",b"A traves de los siglos, la humanidad ha forjado su camino, enfrentando desafios y celebrando triunfos, tejiendo historias que quedan grabadas en el tejido del tiempo, como un testimonio de nuestra existencia en este vasto universo."]

# %%
seguridad=[64,128,256,512,1024]

# %%
llaves=[]
firmas=[]
verificacion=[]
for i in range(len(mensajes)):
    print("***********************************************************")
    print("\t\t\t Para el mensaje número ",i)
    print(mensajes[i])
    llave_tiempo       =[]
    firma_tiempo       =[]
    verificacion_tiempo=[]
    for j in range(len(seguridad)):
        print("Con el nivel de seguridad ",seguridad[j])
        inicio=time.time()
        sk = falcon.SecretKey(seguridad[j])
        pk = falcon.PublicKey(sk) 
        fin=time.time()
        llave_tiempo.append(-inicio+fin)
        print("El tiempo que tomó la generación de las llaves: ",-inicio+fin)
        
        inicio=time.time()
        sig = sk.sign(mensajes[i])
        fin=time.time()
        firma_tiempo.append(-inicio+fin)
        print("El tiempo que tomó firmar el mensaje: ",-inicio+fin)
        
        inicio=time.time()
        veri=pk.verify(mensajes[i], sig)
        fin=time.time()
        verificacion_tiempo.append(-inicio+fin)
        print("La verificación fue: ",veri)
        print("El tiempo de la verificación fue de: ",-inicio+fin)
        
    llaves.append(llave_tiempo)
    firmas.append(firma_tiempo)
    verificacion.append(verificacion_tiempo)
# Out:
# ***********************************************************
# 			 Para el mensaje número  0
# b'Sol y mar.'
# Con el nivel de seguridad  64
# El tiempo que tomó la generación de las llaves:  2.4732961654663086
# El tiempo que tomó firmar el mensaje:  0.003222942352294922
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0005099773406982422
# Con el nivel de seguridad  128
# El tiempo que tomó la generación de las llaves:  3.446840524673462
# El tiempo que tomó firmar el mensaje:  0.006108522415161133
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0010540485382080078
# Con el nivel de seguridad  256
# El tiempo que tomó la generación de las llaves:  2.062403917312622
# El tiempo que tomó firmar el mensaje:  0.012708425521850586
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.002163410186767578
# Con el nivel de seguridad  512
# El tiempo que tomó la generación de las llaves:  2.6665444374084473
# El tiempo que tomó firmar el mensaje:  0.02637028694152832
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0046024322509765625
# Con el nivel de seguridad  1024
# El tiempo que tomó la generación de las llaves:  14.599479913711548
# El tiempo que tomó firmar el mensaje:  0.05147671699523926
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.009952545166015625
# ***********************************************************
# 			 Para el mensaje número  1
# b'Cielo azul y sol.'
# Con el nivel de seguridad  64
# El tiempo que tomó la generación de las llaves:  1.1297743320465088
# El tiempo que tomó firmar el mensaje:  0.003369569778442383
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0005164146423339844
# Con el nivel de seguridad  128
# El tiempo que tomó la generación de las llaves:  0.5120360851287842
# El tiempo que tomó firmar el mensaje:  0.006227731704711914
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0010821819305419922
# Con el nivel de seguridad  256
# El tiempo que tomó la generación de las llaves:  0.723522424697876
# El tiempo que tomó firmar el mensaje:  0.013248205184936523
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0022649765014648438
# Con el nivel de seguridad  512
# El tiempo que tomó la generación de las llaves:
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.010197877883911133
# ***********************************************************
# 			 Para el mensaje número  7
# b'A traves de los siglos, la humanidad ha forjado su camino, enfrentando desafios y celebrando triunfos, tejiendo historias que quedan grabadas en el tejido del tiempo, como un testimonio de nuestra existencia en este vasto universo.'
# Con el nivel de seguridad  64
# El tiempo que tomó la generación de las llaves:  0.12765169143676758
# El tiempo que tomó firmar el mensaje:  0.0030515193939208984
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0005209445953369141
# Con el nivel de seguridad  128
# El tiempo que tomó la generación de las llaves:  0.4033203125
# El tiempo que tomó firmar el mensaje:  0.01280069351196289
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0010707378387451172
# Con el nivel de seguridad  256
# El tiempo que tomó la generación de las llaves:  0.9441194534301758
# El tiempo que tomó firmar el mensaje:  0.012475252151489258
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0021567344665527344
# Con el nivel de seguridad  512
# El tiempo que tomó la generación de las llaves:  2.1583712100982666
# El tiempo que tomó firmar el mensaje:  0.025660991668701172
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.004613399505615234
# Con el nivel de seguridad  1024
# El tiempo que tomó la generación de las llaves:  15.528030157089233
# El tiempo que tomó firmar el mensaje:  0.05001568794250488
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.010032415390014648

# %%
import matplotlib.pyplot as plt
for i in range(len(llaves)):
    plt.plot(llaves[i],label=str("Mensaje ")+str(i))
plt.grid()
plt.xticks(range(0,5,1),seguridad)
plt.xlabel("Nivel de seguridad")
plt.ylabel("Tiempo(s)")
plt.title("Tiempo de generación de las firmas")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
for i in range(len(firmas)):
    plt.plot(firmas[i],label=str("Mensaje ")+str(i))
plt.grid()
plt.xticks(range(0,5,1),seguridad)
plt.xlabel("Nivel de seguridad")
plt.ylabel("Tiempo(s)")
plt.title("Tiempo de firmar un mensaje")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
for i in range(len(verificacion)):
    plt.plot(verificacion[i],label=str("Mensaje ")+str(i))
plt.grid()
plt.xticks(range(0,5,1),seguridad)
plt.xlabel("Nivel de seguridad")
plt.ylabel("Tiempo(s)")
plt.title("Tiempo de verificación")
plt.legend()
plt.show()

# %%
llaves=[]
firmas=[]
verificacion=[]
for i in range(len(mensajes)):
    print("***********************************************************")
    print("\t\t\t Para el mensaje número ",i)
    print(mensajes[i])
    llave_tiempo       =[]
    firma_tiempo       =[]
    verificacion_tiempo=[]
    for j in range(len(seguridad)):
        print("Con el nivel de seguridad ",seguridad[j])
        inicio=time.time()
        sk = falcon.SecretKey(seguridad[j])
        pk = falcon.PublicKey(sk) 
        fin=time.time()
        llave_tiempo.append(-inicio+fin)
        print("El tiempo que tomó la generación de las llaves: ",-inicio+fin)
        
        inicio=time.time()
        sig = sk.sign(mensajes[i])
        fin=time.time()
        firma_tiempo.append(-inicio+fin)
        print("El tiempo que tomó firmar el mensaje: ",-inicio+fin)
        
        inicio=time.time()
        veri=pk.verify(mensajes[i], sig)
        fin=time.time()
        verificacion_tiempo.append(-inicio+fin)
        print("La verificación fue: ",veri)
        print("El tiempo de la verificación fue de: ",-inicio+fin)
        
    llaves.append(llave_tiempo)
    firmas.append(firma_tiempo)
    verificacion.append(verificacion_tiempo)
# Out:
# ***********************************************************
# 			 Para el mensaje número  0
# b'Sol y mar.'
# Con el nivel de seguridad  64
# El tiempo que tomó la generación de las llaves:  0.9512186050415039
# El tiempo que tomó firmar el mensaje:  0.0037584304809570312
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0005717277526855469
# Con el nivel de seguridad  128
# El tiempo que tomó la generación de las llaves:  0.8448882102966309
# El tiempo que tomó firmar el mensaje:  0.006751537322998047
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0010602474212646484
# Con el nivel de seguridad  256
# El tiempo que tomó la generación de las llaves:  1.0620934963226318
# El tiempo que tomó firmar el mensaje:  0.012186527252197266
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0021219253540039062
# Con el nivel de seguridad  512
# El tiempo que tomó la generación de las llaves:  2.6842403411865234
# El tiempo que tomó firmar el mensaje:  0.025817155838012695
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.004901409149169922
# Con el nivel de seguridad  1024
# El tiempo que tomó la generación de las llaves:  12.153165340423584
# El tiempo que tomó firmar el mensaje:  0.05040454864501953
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.009919404983520508
# ***********************************************************
# 			 Para el mensaje número  1
# b'Cielo azul y sol.'
# Con el nivel de seguridad  64
# El tiempo que tomó la generación de las llaves:  1.3325960636138916
# El tiempo que tomó firmar el mensaje:  0.0059778690338134766
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0005085468292236328
# Con el nivel de seguridad  128
# El tiempo que tomó la generación de las llaves:  1.8523480892181396
# El tiempo que tomó firmar el mensaje:  0.006096839904785156
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0010373592376708984
# Con el nivel de seguridad  256
# El tiempo que tomó la generación de las llaves:  1.395667314529419
# El tiempo que tomó firmar el mensaje:  0.012697696685791016
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.009587526321411133
# ***********************************************************
# 			 Para el mensaje número  7
# b'A traves de los siglos, la humanidad ha forjado su camino, enfrentando desafios y celebrando triunfos, tejiendo historias que quedan grabadas en el tejido del tiempo, como un testimonio de nuestra existencia en este vasto universo.'
# Con el nivel de seguridad  64
# El tiempo que tomó la generación de las llaves:  2.095442771911621
# El tiempo que tomó firmar el mensaje:  0.0063266754150390625
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0005388259887695312
# Con el nivel de seguridad  128
# El tiempo que tomó la generación de las llaves:  1.128197431564331
# El tiempo que tomó firmar el mensaje:  0.006606578826904297
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.0010707378387451172
# Con el nivel de seguridad  256
# El tiempo que tomó la generación de las llaves:  0.5800132751464844
# El tiempo que tomó firmar el mensaje:  0.013650894165039062
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.00240325927734375
# Con el nivel de seguridad  512
# El tiempo que tomó la generación de las llaves:  3.2849740982055664
# El tiempo que tomó firmar el mensaje:  0.026509523391723633
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.004595279693603516
# Con el nivel de seguridad  1024
# El tiempo que tomó la generación de las llaves:  20.81287121772766
# El tiempo que tomó firmar el mensaje:  0.05364680290222168
# La verificación fue:  True
# El tiempo de la verificación fue de:  0.01106715202331543

# %%
for i in range(len(llaves)):
    plt.plot(llaves[i],label=str("Mensaje ")+str(i))
plt.grid()
plt.xticks(range(0,5,1),seguridad)
plt.xlabel("Nivel de seguridad")
plt.ylabel("Tiempo(s)")
plt.title("Tiempo de generación de las firmas")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
for i in range(len(firmas)):
    plt.plot(firmas[i],label=str("Mensaje ")+str(i))
plt.grid()
plt.xticks(range(0,5,1),seguridad)
plt.xlabel("Nivel de seguridad")
plt.ylabel("Tiempo(s)")
plt.title("Tiempo de firmar un mensaje")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
for i in range(len(verificacion)):
    plt.plot(verificacion[i],label=str("Mensaje ")+str(i))
plt.grid()
plt.xticks(range(0,5,1),seguridad)
plt.xlabel("Nivel de seguridad")
plt.ylabel("Tiempo(s)")
plt.title("Tiempo de verificación")
plt.legend()
plt.show()

# %%
llaves_pruebas=[]
firmas_pruebas=[]
verificacion_pruebas=[]
Cantidad_pruebas=500
for i in range(len(seguridad)):
    #print("***********************************************************")
    #print("\t\t\t Para el mensaje número ",i)
    #print(mensajes[i])
    llave_tiempo       =[]
    firma_tiempo       =[]
    verificacion_tiempo=[]
    for j in range(Cantidad_pruebas):
        #print("Con el nivel de seguridad ",seguridad[j])
        inicio=time.time()
        sk = falcon.SecretKey(seguridad[i])
        pk = falcon.PublicKey(sk) 
        fin=time.time()
        llave_tiempo.append(-inicio+fin)
        #print("El tiempo que tomó la generación de las llaves: ",-inicio+fin)
        
        inicio=time.time()
        sig = sk.sign(b"hola")
        fin=time.time()
        firma_tiempo.append(-inicio+fin)
        #print("El tiempo que tomó firmar el mensaje: ",-inicio+fin)
        
        inicio=time.time()
        veri=pk.verify(b"hola", sig)
        fin=time.time()
        if veri==False:
            print("Falló verificación")
            break
        verificacion_tiempo.append(-inicio+fin)
        #print("La verificación fue: ",veri)
        #print("El tiempo de la verificación fue de: ",-inicio+fin)
    print("Terminado las pruebas con nivel de seguridad ",seguridad[i])    
    llaves_pruebas.append(llave_tiempo)
    firmas_pruebas.append(firma_tiempo)
    verificacion_pruebas.append(verificacion_tiempo)
# Out:
# Terminado las pruebas con nivel de seguridad  64
# Terminado las pruebas con nivel de seguridad  128
# Terminado las pruebas con nivel de seguridad  256
# Terminado las pruebas con nivel de seguridad  512
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15675/3881831665.py in <module>
#      13         #print("Con el nivel de seguridad ",seguridad[j])
#      14         inicio=time.time()
# ---> 15         sk = falcon.SecretKey(seguridad[i])
#      16         pk = falcon.PublicKey(sk)
#      17         fin=time.time()
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/falcon.py in __init__(self, n, polys)
#     228         # Compute NTRU polynomials f, g, F, G verifying fG - gF = q mod Phi
#     229         if polys is None:
# --> 230             self.f, self.g, self.F, self.G = ntru_gen(n)
#     231         else:
#     232             [f, g, F, G] = polys
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in ntru_gen(n)
#     236             continue
#     237         try:
# --> 238             F, G = ntru_solve(f, g)
#     239             F = [int(coef) for coef in F]
#     240             G = [int(coef) for coef in G]
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in ntru_solve(f, g)
#     181         fp = field_norm(f)
#     182         gp = field_norm(g)
# --> 183         Fp, Gp = ntru_solve(fp, gp)
#     184         F = karamul(lift(Fp), galois_conjugate(g))
#     185         G = karamul(lift(Gp), galois_conjugate(f))
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in ntru_solve(f, g)
#     181         fp = field_norm(f)
#     182         gp = field_norm(g)
# --> 183         Fp, Gp = ntru_solve(fp, gp)
#     184         F = karamul(lift(Fp), galois_conjugate(g))
#     185         G = karamul(lift(Gp), galois_conjugate(f))
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in ntru_solve(f, g)
#     181         fp = field_norm(f)
#     182         gp = field_norm(g)
# --> 183         Fp, Gp = ntru_solve(fp, gp)
#     184         F = karamul(lift(Fp), galois_conjugate(g))
#     185         G = karamul(lift(Gp), galois_conjugate(f))
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in ntru_solve(f, g)
#     181         fp = field_norm(f)
#     182         gp = field_norm(g)
# --> 183         Fp, Gp = ntru_solve(fp, gp)
#     184         F = karamul(lift(Fp), galois_conjugate(g))
#     185         G = karamul(lift(Gp), galois_conjugate(f))
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in ntru_solve(f, g)
#     181         fp = field_norm(f)
#     182         gp = field_norm(g)
# --> 183         Fp, Gp = ntru_solve(fp, gp)
#     184         F = karamul(lift(Fp), galois_conjugate(g))
#     185         G = karamul(lift(Gp), galois_conjugate(f))
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in ntru_solve(f, g)
#     181         fp = field_norm(f)
#     182         gp = field_norm(g)
# --> 183         Fp, Gp = ntru_solve(fp, gp)
#     184         F = karamul(lift(Fp), galois_conjugate(g))
#     185         G = karamul(lift(Gp), galois_conjugate(f))
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in ntru_solve(f, g)
#     181         fp = field_norm(f)
#     182         gp = field_norm(g)
# --> 183         Fp, Gp = ntru_solve(fp, gp)
#     184         F = karamul(lift(Fp), galois_conjugate(g))
#     185         G = karamul(lift(Gp), galois_conjugate(f))
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in ntru_solve(f, g)
#     181         fp = field_norm(f)
#     182         gp = field_norm(g)
# --> 183         Fp, Gp = ntru_solve(fp, gp)
#     184         F = karamul(lift(Fp), galois_conjugate(g))
#     185         G = karamul(lift(Gp), galois_conjugate(f))
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in ntru_solve(f, g)
#     184         F = karamul(lift(Fp), galois_conjugate(g))
#     185         G = karamul(lift(Gp), galois_conjugate(f))
# --> 186         F, G = reduce(f, g, F, G)
#     187         return F, G
#     188
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in reduce(f, g, F, G)
#     121         # Because we work in finite precision to reduce very large polynomials,
#     122         # we may need to perform the reduction several times.
# --> 123         Size = max(53, bitsize(min(F)), bitsize(max(F)), bitsize(min(G)), bitsize(max(G)))
#     124         if Size < size:
#     125             break
#
# ~/Estudio/Maestria/Tesis/Falcon/falcon.py/ntrugen.py in bitsize(a)
#      98     while val:
#      99         res += 8
# --> 100         val >>= 8
#     101     return res
#     102
#
# KeyboardInterrupt:

# %%
q
# Out:
# [[ 3.71982  2.69925  0.23376  0.22981  0.53565]
#  [ 0.70268  2.08602  0.721    1.6595   0.19603]
#  [ 1.7355   1.54588  0.74427  0.74059  1.18406]
#  [ 4.96485 10.83706  1.81983  2.36521  2.83131]
#  [15.64531 23.22892 13.45231 16.92168 16.56994]] 17.163633251190184

# %%
12*500/60

# %%
for i in range(len(llaves_pruebas)):
    plt.plot(llaves_pruebas[i],label=str(seguridad[i]))
plt.grid()
#plt.xticks(range(0,3,1),seguridad)
plt.xlabel("Cantidad de pruebas")
plt.ylabel("Tiempo(s)")
plt.title("Tiempo de de generación de llaves")
plt.legend()
plt.show()

# %%
for i in range(len(firmas_pruebas)):
    plt.plot(firmas_pruebas[i],label=str(seguridad[i]))
plt.grid()
#plt.xticks(range(0,3,1),seguridad)
plt.xlabel("Cantidad de pruebas")
plt.ylabel("Tiempo(s)")
plt.title("Tiempo de de generación de firmas")
plt.legend()
plt.show()

# %%
for i in range(len(verificacion_pruebas)):
    plt.plot(verificacion_pruebas[i],label=str(seguridad[i]))
plt.grid()
#plt.xticks(range(0,3,1),seguridad)
plt.xlabel("Cantidad de pruebas")
plt.ylabel("Tiempo(s)")
plt.title("Tiempo de de generación de verificación")
plt.legend()
plt.show()

# %%
import numpy as np
for i in range(len(seguridad)):
    print("El promedio de generación de llaves para ",str(seguridad[i]),np.mean(llaves_pruebas[i]))
    print("El promedio para firmar el mensaje",str(seguridad[i]),np.mean(firmas_pruebas[i]))
    print("El promedio de la verificacion ",str(seguridad[i]),np.mean(verificacion_pruebas[i]))
    print("**********************************************************************")
# Out:
# El promedio de generación de llaves para  64 0.7901839957237243
# El promedio para firmar el mensaje 64 0.0034148311614990235
# El promedio de la verificacion  64 0.000547884464263916
# **********************************************************************
# El promedio de generación de llaves para  128 1.2323462991714478
# El promedio para firmar el mensaje 128 0.006497729301452637
# El promedio de la verificacion  128 0.0011168012619018554
# **********************************************************************
# El promedio de generación de llaves para  256 1.583732497215271
# El promedio para firmar el mensaje 256 0.012860272884368897
# El promedio de la verificacion  256 0.0022757534980773924
# **********************************************************************
# El promedio de generación de llaves para  512 3.6844711899757385
# El promedio para firmar el mensaje 512 0.026156229496002197
# El promedio de la verificacion  512 0.004677585601806641
# **********************************************************************
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_15675/2564726800.py in <module>
#       1 import numpy as np
#       2 for i in range(len(seguridad)):
# ----> 3     print("El promedio de generación de llaves para ",str(seguridad[i]),np.mean(llaves_pruebas[i]))
#       4     print("El promedio para firmar el mensaje",str(seguridad[i]),np.mean(firmas_pruebas[i]))
#       5     print("El promedio de la verificacion ",str(seguridad[i]),np.mean(verificacion_pruebas[i]))
#
# IndexError: list index out of range

# %%
import csv
import numpy as np

# Crear una matriz de ejemplo 3x500
matriz = np.random.randint(1, 1000, size=(3, 500))

# Agregar títulos de columnas
titulos = seguridad

# Nombre del archivo CSV
archivo_csv = "llaves_pruebas.csv"

# Guardar la matriz en el archivo CSV
with open(archivo_csv, mode='w', newline='') as archivo:
    escritor_csv = csv.writer(archivo)
    
    # Escribir títulos de columnas
    escritor_csv.writerow(titulos)
    
    # Escribir datos por columnas
    for i in range(500):
        fila = [llaves_pruebas[j][i] for j in range(3)]
        escritor_csv.writerow(fila)

# %%
import csv
import numpy as np

# Crear una matriz de ejemplo 3x500
matriz = np.random.randint(1, 1000, size=(3, 500))

# Agregar títulos de columnas
titulos = seguridad
# Nombre del archivo CSV
archivo_csv = "firmas_pruebas.csv"

# Guardar la matriz en el archivo CSV
with open(archivo_csv, mode='w', newline='') as archivo:
    escritor_csv = csv.writer(archivo)
    
    # Escribir títulos de columnas
    escritor_csv.writerow(titulos)
    
    # Escribir datos por columnas
    for i in range(500):
        fila = [firmas_pruebas[j][i] for j in range(3)]
        escritor_csv.writerow(fila)

# %%
import csv
import numpy as np

# Crear una matriz de ejemplo 3x500
matriz = np.random.randint(1, 1000, size=(3, 500))

# Agregar títulos de columnas
titulos = seguridad
# Nombre del archivo CSV
archivo_csv = "verificacion_pruebas.csv"

# Guardar la matriz en el archivo CSV
with open(archivo_csv, mode='w', newline='') as archivo:
    escritor_csv = csv.writer(archivo)
    
    # Escribir títulos de columnas
    escritor_csv.writerow(titulos)
    
    # Escribir datos por columnas
    for i in range(500):
        fila = [verificacion_pruebas[j][i] for j in range(3)]
        escritor_csv.writerow(fila)
